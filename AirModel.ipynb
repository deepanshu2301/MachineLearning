# %% [markdown]
# AIR QUALITY PREDICTION

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataT=pd.read_csv("Datasets/Regression_Data/Train.csv")

# %%
print(dataT.shape)

dataT=dataT.values

X=dataT[:,0:5]
Y=dataT[:,5:6]
print(X.shape)
print(Y.shape)
# Out:
# (1600, 6)
# (1600, 5)
# (1600, 1)

# %%
print(X[:,4])
print(Y[:,0])
# Out:
# [ 0.52566183  0.59799685 -0.18736416 ...  0.44251965  0.73633394
#   1.4595758 ]
# [ -82.15466656  -48.89796018   77.2703707  ... -107.51050797  -47.34155781
#  -115.93900296]

# %%
datat=pd.read_csv("Datasets/Regression_Data/Test.csv")
print(datat.shape)
# Out:
# (400, 6)

# %%
datat=datat.values
x=datat[:,0:5]
y=datat[:,5:6]
print(x.shape)
print(y.shape)
# Out:
# (400, 5)
# (400, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression(normalize=True)
lr.fit(X,Y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [[29.68187118 92.66247759  8.28062089 44.76773522  2.51916121]]
# [4.99096674]

# %%
print("Training Score: %0.3f"%lr.score(X,Y))
print("Testing Score: %0.3f"%lr.score(x,y))
# Out:
# Training Score: 0.966
# Testing Score: 0.969

# %%
for i in range(0,5):
    plt.scatter(X[:,i],Y)
    plt.show()
